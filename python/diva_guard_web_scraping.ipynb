# %%
# !pip install selenium

# %%
# !apt-get update

# %%
# !apt-get install -y chromium-browser

# %%
# !apt install chromium-chromedriver

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
# !ls /usr/lib/chromium-browser/chromedriver
# Out:
# /usr/lib/chromium-browser/chromedriver

# %%
def web_driver():
  options=webdriver.ChromeOptions()
  options.add_argument("--verbose")
  options.add_argument("--no-sandbox")
  options.add_argument("--headless")
  options.add_argument("--disable-gpu")
  options.add_argument("--window-size=1920,1200")
  options.add_argument("--disable-dev-shm-usage")
  driver = webdriver.Chrome(options=options)
  return driver

driver = web_driver()

# %%
texts=[]
locations=[]
categories=[]
date_time=[]

# %%
import pandas as pd

main_link = "https://public.tableau.com/app/profile/mehul.sharma3900/viz/Safecity_Dashboard_Delhi_final/DelhiStory"

for i in range(1, 5):
    link = main_link+str(i)
    driver.get(link)

    content = driver.page_source
    soup = BeautifulSoup(content)

    for a in soup.find_all('div', attrs={'class':'r_details'}):

        txt = a.find('div', attrs={'class':'r_description'})
        location = a.find('p', attrs={'class':'r_location'})
        dt = a.find('p', attrs={'class':'r_date r-3 bottom-cap'})

        texts.append(txt.text)
        locations.append(location.text)
        date_time.append(dt.text)


    for a in soup.find_all('div', attrs={'class':'r_media'}):
        category = a.find('span', attrs={'class':'r_cat-desc'})
        categories.append(category.text)

# %%
df = pd.DataFrame({'Category': categories, 'Location': locations, 'Incident': texts, 'Date/Time': date_time})
df.to_csv('web_data.csv', index=False, encoding='utf-8')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
police_stations = []
address = []

# %%
last_stri = """Anand Parbat Police Station
Address: Gali Number 10, Anand Parbat Industrial Area, Anand Parbat, New Delhi, 110005

Nabi Karim Police Station
Address: Babu Ram Solanki Marg, Nabi Karim, Sadar Bazaar, New Delhi, 110055

Chandani Mahal Police Station
Address: Asaf Ali Road, near Delight Cinema, New Delhi, Delhi, 110006

Jama Masjid Police Station
Address: Gate – 3, 1424, Patel Gali Rd, Opposite, Dariba Kalan Rd, before, Jama Masjid, Old Delhi, New Delhi, Delhi, 110006

Desh Bandhu Gupta Road Police Station
Address: 3378,, 4Q, DB Gupta Road, Block 44Q, Beadonpura, Karol Bagh, New Delhi, Delhi, 110005

Kamla Market Police Station
Address: near Kamla Market, Kamla Market, Ajmeri Gate, New Delhi, Delhi, 110002

Darya Ganj Police Station
Address: Bahadur Shah Zafar Marg, Daryaganj, New Delhi, Delhi, 110002

Karol Bagh Police Station
Address: 2682/1, Ajmal Khan Rd, Block 46, Beadonpura, Karol Bagh, New Delhi, Delhi, 110005

Hauz Qazi Police Station
Address: Hauz Qazi Chowk, Bazar Sirkiwalan, Kaccha Pandit Main Bazar, Lal Kuan Bazar, Chandni Chowk, New Delhi, Delhi, 110006

Parsad Nagar Police Station
Address: 30, Tank Rd, Prasad Nagar, Dev Nagar, Karol Bagh, New Delhi, Delhi, 110005

I.P. Estate Police Station
Address: Mahatma Gandhi Marg, Gas Turbine Power Station, IP Estate, New Delhi, Delhi, 110002

Patel Nagar Police Station
Address: Main Patel Rd, Block B, West Patel Nagar, Patel Nagar, New Delhi, Delhi, 110008

Address:B-88-5, 86-5, Satguru Ram Singh Rd,  Mayapuri Industrial Area Phase I, Mayapuri, Delhi, 110064

Khyala Police Station
Address: A Block Rd, NEAR 830, J. J. Colony, Khayala, Vishnu Garden, Delhi, 110027

Janak Puri Police Station
Address: 8, Janakpuri District Center, Janakpuri, Delhi, 110058
"""

# %%
lst = last_stri.split("\n ")

# %%
for i in lst:
    i.strip()

lst = lst[0].split('\n')
lst
# Out:
# ['Anand Parbat Police Station',
#  'Address: Gali Number 10, Anand Parbat Industrial Area, Anand Parbat, New Delhi, 110005',
#  '',
#  'Nabi Karim Police Station',
#  'Address: Babu Ram Solanki Marg, Nabi Karim, Sadar Bazaar, New Delhi, 110055',
#  '',
#  'Chandani Mahal Police Station',
#  'Address: Asaf Ali Road, near Delight Cinema, New Delhi, Delhi, 110006',
#  '',
#  'Jama Masjid Police Station',
#  'Address: Gate – 3, 1424, Patel Gali Rd, Opposite, Dariba Kalan Rd, before, Jama Masjid, Old Delhi, New Delhi, Delhi, 110006',
#  '',
#  'Desh Bandhu Gupta Road Police Station',
#  'Address: 3378,, 4Q, DB Gupta Road, Block 44Q, Beadonpura, Karol Bagh, New Delhi, Delhi, 110005',
#  '',
#  'Kamla Market Police Station',
#  'Address: near Kamla Market, Kamla Market, Ajmeri Gate, New Delhi, Delhi, 110002',
#  '',
#  'Darya Ganj Police Station',
#  'Address: Bahadur Shah Zafar Marg, Daryaganj, New Delhi, Delhi, 110002',
#  '',
#  'Karol Bagh Police Station',
# ...

# %%
for i in range(len(lst)):
    if(i%3==0):
        police_stations.append(lst[i])
    elif(i%3==1):
        address.append(lst[i])

# %%
address = [i.replace("Address:", '').strip() for i in address]
police_stations = [i.strip() for i in police_stations]
address
# Out:
# ['Gali Number 10, Anand Parbat Industrial Area, Anand Parbat, New Delhi, 110005',
#  'Babu Ram Solanki Marg, Nabi Karim, Sadar Bazaar, New Delhi, 110055',
#  'Asaf Ali Road, near Delight Cinema, New Delhi, Delhi, 110006',
#  'Gate – 3, 1424, Patel Gali Rd, Opposite, Dariba Kalan Rd, before, Jama Masjid, Old Delhi, New Delhi, Delhi, 110006',
#  '3378,, 4Q, DB Gupta Road, Block 44Q, Beadonpura, Karol Bagh, New Delhi, Delhi, 110005',
#  'near Kamla Market, Kamla Market, Ajmeri Gate, New Delhi, Delhi, 110002',
#  'Bahadur Shah Zafar Marg, Daryaganj, New Delhi, Delhi, 110002',
#  '2682/1, Ajmal Khan Rd, Block 46, Beadonpura, Karol Bagh, New Delhi, Delhi, 110005',
#  'Hauz Qazi Chowk, Bazar Sirkiwalan, Kaccha Pandit Main Bazar, Lal Kuan Bazar, Chandni Chowk, New Delhi, Delhi, 110006',
#  '30, Tank Rd, Prasad Nagar, Dev Nagar, Karol Bagh, New Delhi, Delhi, 110005',
#  'Mahatma Gandhi Marg, Gas Turbine Power Station, IP Estate, New Delhi, Delhi, 110002',
# ...

# %%
df = pd.DataFrame({'Name': police_stations, 'Location': address})
df.to_csv('police_station_data.csv', index=False, encoding='utf-8')
